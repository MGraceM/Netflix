# %%
import pandas as pd

# %%
pd.read_csv('netflix_data.csv')
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
movie=pd.read_csv('netflix_data.csv')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   duration      7787 non-null   int64
#  9   description   7787 non-null   object
#  10  genre         7787 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 669.3+ KB

# %%
movie.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
new_movie=movie.sort_values(by=["release_year","duration"])[["release_year","duration"]]

# %%
print(new_movie)
# Out:
#       release_year  duration
# 4867          1925         1
# 6117          1942        18
# 4960          1942        52
# 7679          1943        45
# 7342          1943        61
# ...            ...       ...
# 5859          2021        97
# 1355          2021        98
# 7551          2021       102
# 7644          2021       102
# 4710          2021       116
#
# [7787 rows x 2 columns]

# %%
new_movie=new_movie.sort_values(by= "release_year")

# %%
print(new_movie)
# Out:
#       release_year  duration
# 4867          1925         1
# 6117          1942        18
# 4960          1942        52
# 7679          1943        45
# 7342          1943        61
# ...            ...       ...
# 2327          2021         1
# 980           2021         1
# 7644          2021       102
# 1440          2021         3
# 4710          2021       116
#
# [7787 rows x 2 columns]

# %%
new_movie[(new_movie["release_year"]>=2011) & (new_movie["release_year"]<=2020)]
# Out:
#       release_year  duration
# 7776          2011       104
# 6264          2011       105
# 6509          2011       105
# 2079          2011       106
# 3256          2011       106
# ...            ...       ...
# 7661          2020         1
# 7650          2020         1
# 7630          2020         1
# 7612          2020         1
# 7670          2020         1
#
# [6406 rows x 2 columns]

# %%
movie2=new_movie[(new_movie["release_year"]>=2011) & (new_movie["release_year"]<=2020)]

# %%
years=[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
duration=[103,101,99,100,100,95,95,96,93,90]

# %%
movie_dict ="years","duration"

# %%
movie_dict
# Out:
# ('years', 'duration')

# %%
import pandas as pd

# %%
durations_df=movie_dict

# %%
print("duration_df")
# Out:
# duration_df

# %%
netflix_df=pd.read_csv('netflix_data.csv')

# %%
netflix_df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_df_movies_only = netflix_df[netflix_df["type"]=="Movie"]

# %%
netflix_df_movies_only.head()
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
# 3      s4  Movie      9        Shane Acker
# 4      s5  Movie     21     Robert Luketic
# 6      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
# 6       June 1, 2020          2019        95
#
# ...

# %%
netflix_movies_col_subset = netflix_df_movies_only[["title","country","release_year","duration","genre"]]

# %%
netflix_movies_col_subset.head(5)
# Out:
#    title        country  release_year  duration          genre
# 1   7:19         Mexico          2016        93         Dramas
# 2  23:59      Singapore          2011        78  Horror Movies
# 3      9  United States          2009        80         Action
# 4     21  United States          2008       123         Dramas
# 6    122          Egypt          2019        95  Horror Movies

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/4d/9c/65830d4a56c47f5283eaa244dc1228c5da9c844a9f999ebcc2e69bf6cc65/matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/16/09/989b982322439faa4bafffcd669e6f942b38fee897c2664c987bcd091dec/contourpy-1.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/52/65/aaa3d2b7a292d93cc2cf1c534d03ba3f744e480f15b3b2ab6ad68189f7ee/fonttools-4.42.0-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/153.7 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/153.7 kB ? eta -:--:--
#      ----------------- ------------------- 71.7/153.7 kB 653.6 kB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
netflix_movies_col_subset.plot.scatter("release_year","duration",color="r");
plt.title('Movie Duration by Year Release')
# Out:
# Text(0.5, 1.0, 'Movie Duration by Year Release')

# %%
Dataframe_short_movies=netflix_movies_col_subset[netflix_movies_col_subset["duration"]<60]

# %%
Dataframe_short_movies.head(20)
# Out:
#                                                  title         country  \
# 35                                           #Rucker50   United States
# 55                 100 Things to do Before High School   United States
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...             NaN
# 101                                  3 Seconds Divorce          Canada
# 146                                     A 3 Minute Hug          Mexico
# 162  A Christmas Special: Miraculous: Tales of Lady...          France
# 171                         A Family Reunion Christmas   United States
# 177                    A Go! Go! Cory Carson Christmas   United States
# 178                    A Go! Go! Cory Carson Halloween             NaN
# 179                  A Go! Go! Cory Carson Summer Camp             NaN
# 181             A Grand Night In: The Story of Aardman  United Kingdom
# 200                            A Love Song for Latasha   United States
# ...

# %%
color=['red','blue','green','black']
for genre, row in Dataframe_short_movies.iterrows() :
     if row['genre'] =="Children":
        colors.append('red')
     elif row['genre'] == "Documentaries" :
        colors.append('blue')
     elif row['genre'] == "Stand-Up" :
        colors.append('green')  
     else:
        colors.append('black')

# %%
Dataframe_short_movies.head(10)
# Out:
#                                                  title        country  \
# 35                                           #Rucker50  United States
# 55                 100 Things to do Before High School  United States
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...            NaN
# 101                                  3 Seconds Divorce         Canada
# 146                                     A 3 Minute Hug         Mexico
# 162  A Christmas Special: Miraculous: Tales of Lady...         France
# 171                         A Family Reunion Christmas  United States
# 177                    A Go! Go! Cory Carson Christmas  United States
# 178                    A Go! Go! Cory Carson Halloween            NaN
# 179                  A Go! Go! Cory Carson Summer Camp            NaN
#
#      release_year  duration          genre
# 35           2016        56  Documentaries
# 55           2014        44  Uncategorized
# 67           2017        37  Uncategorized
# ...

# %%
netflix_movies_col_subset.plot.scatter("release_year","duration");
plt.title('Movie Duration by Year Release')
# Out:
# Text(0.5, 1.0, 'Movie Duration by Year Release')

# %%
netflix_movies_col_subset.plot.scatter("release_year","duration",color='red');
plt.title('Movie Duration by Year Release')
# Out:
# Text(0.5, 1.0, 'Movie Duration by Year Release')

# %%
a="are movies getting shorter="
b='yes'
print('a'+'b')
